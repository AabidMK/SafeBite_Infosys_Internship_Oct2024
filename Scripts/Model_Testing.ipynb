# %%
import pandas as pd
import joblib

# %%
loaded_encoder = joblib.load("leave_one_out_encoder.pkl")
loaded_model = joblib.load("best_random_forest_model.pkl")

unseen_data = pd.read_csv('sample.csv')
print("Data, Model and encoder loaded successfully")
# Out:
# Data, Model and encoder loaded successfully

# %%
loaded_encoder
# Out:
# LeaveOneOutEncoder(cols=['Food Product', 'Main Ingredient', 'Sweetener',
#                          'Fat/Oil', 'Seasoning', 'Allergens'])

# %%
# categorical_columns = unseen_data.select_dtypes(include=['object']).columns

# unseen_data_encoded = loaded_encoder.transform(unseen_data[categorical_columns])

# unseen_data = pd.concat([unseen_data.drop(categorical_columns, axis=1), unseen_data_encoded], axis=1)

# %%
# predictions = loaded_model.predict(unseen_data)

# print("Predictions on unseen_data", predictions)

# %%
# # Step 1: Verify expected features from the encoder
# expected_features = loaded_encoder.feature_names_in_  # Features used during training
# print("Expected features from encoder:", expected_features)

# # Step 2: Ensure unseen data has the correct columns
# # Add a placeholder for the missing 'Prediction' column
# # if 'Prediction' not in unseen_data.columns:
# #     unseen_data['Prediction'] = 0  # Placeholder value

# # Filter unseen data to only include columns present in expected features
# available_features = unseen_data.columns.intersection(expected_features)
# unseen_data_filtered = unseen_data[available_features]
# print("Unseen data columns after filtering:", unseen_data_filtered.columns)
# Step 3: Transform unseen data
categorical_columns = unseen_data.select_dtypes(include=['object']).columns

unseen_data_encoded = loaded_encoder.transform(unseen_data[categorical_columns])

unseen_data = pd.concat([unseen_data.drop(categorical_columns, axis=1), unseen_data_encoded], axis=1)

# # Step 4: Drop the 'Prediction' column from encoded data before prediction
# # Identify the encoded column names
# encoded_feature_names = loaded_encoder.get_feature_names_out()
# print("Encoded feature names:", encoded_feature_names)

# # Remove any 'Prediction' related features
# encoded_data_for_model = encoded_unseen_data.loc[:, ~encoded_unseen_data.columns.str.contains('Prediction')]
# print("Encoded data for prediction columns:", encoded_data_for_model.columns)
unseen_data
# # Step 5: Make predictions
# Out:
#    Price ($)  Customer rating (Out of 5)  Food Product  Main Ingredient  \
# 0       2.99                         4.2     12.402356        12.402356
# 1       4.49                         4.5     12.402356         9.720000
# 2       3.25                         3.8     12.402356        12.402356
# 3       5.75                         4.7     12.402356        13.792500
# 4       4.00                         4.0     11.245000        11.790000
# 5       6.50                         4.6     12.402356        13.760000
# 6       3.75                         4.3     12.402356        12.402356
# 7       2.50                         3.9     12.402356        12.402356
# 8       5.25                         4.8     12.402356        12.402356
# 9       6.00                         4.1     12.402356        12.402356
#
#    Sweetener    Fat/Oil  Seasoning  Allergens
# 0  13.235000  12.402356  12.246250  12.402356
# 1  12.402356  10.597778  12.402356  12.402356
# ...

# %%
predictions = loaded_model.predict(unseen_data)

# Step 6: Add predictions to the original unseen dataset
unseen_data['Predictions'] = predictions

# Step 7: Save predictions to a CSV file
output_path = 'predictions_output.csv'
unseen_data.to_csv(output_path, index=False)
print(f"Predictions saved to '{output_path}'")
# Out:
# Predictions saved to 'predictions_output.csv'
