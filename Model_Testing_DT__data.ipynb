# %% [markdown]
# <a href="https://colab.research.google.com/github/AabidMK/SafeBite_Infosys_Internship_Oct2024/blob/Pranav/Model_Testing_DT__data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import joblib
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
original_data = pd.read_csv('/content/drive/My Drive/food allergy/Allergen_Status_of_Food_Products.csv')
encoded_data = pd.read_csv('/content/drive/My Drive/preprocessed_d.csv')

# %%
# !pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 2.2 MB/s eta 0:00:00
# ...

# %%
loo_encoder = joblib.load('/content/drive/My Drive/loo_encoder.joblib')
model_path = '/content/drive/My Drive/dt_model.joblib'
model = joblib.load(model_path)

# %%
example_data = pd.DataFrame({
    'Food Product': ['Gluten-Free Chocolate Cake', 'Chocolate Cake'],
    'Main Ingredient': ['Almond flour', 'Wheat flour'],
    'Sweetener': ['Coconut sugar', 'Sugar'],
    'Fat/Oil': ['Coconut oil', 'Butter'],
    'Seasoning': ['Vanilla extract, Cocoa', 'Vanilla extract, Cocoa'],
    'Allergens': ['None', 'Wheat-Dairy'],
    'Price': [7.50, 7.55],
    'Customer rating': [4.5, 4.6]
})

# %%
training_features = model.feature_names_in_
training_features
# Out:
# array(['Food Product', 'Main Ingredient', 'Sweetener', 'Fat/Oil',
#        'Seasoning', 'Allergens', 'Price', 'Customer rating'], dtype=object)

# %%
categorical_cols = ['Food Product', 'Main Ingredient', 'Sweetener', 'Fat/Oil', 'Seasoning', 'Allergens']

# %%
example_data_encoded = loo_encoder.transform(example_data[categorical_cols])
example_data_encoded
# Out:
#    Food Product  Main Ingredient  Sweetener    Fat/Oil  Seasoning  Allergens
# 0     12.397588        12.397588  12.397588  12.397588  12.397588  12.165608
# 1     12.397588        16.355000  12.319891  12.444471  12.397588  12.397588

# %%
encoded_cols = example_data_encoded.columns
encoded_cols
# Out:
# Index(['Food Product', 'Main Ingredient', 'Sweetener', 'Fat/Oil', 'Seasoning',
#        'Allergens'],
#       dtype='object')

# %%
example_data = pd.concat([example_data[['Price', 'Customer rating']], example_data_encoded], axis=1)
example_data
# Out:
#    Price  Customer rating  Food Product  Main Ingredient  Sweetener  \
# 0   7.50              4.5     12.397588        12.397588  12.397588
# 1   7.55              4.6     12.397588        16.355000  12.319891
#
#      Fat/Oil  Seasoning  Allergens
# 0  12.397588  12.397588  12.165608
# 1  12.444471  12.397588  12.397588

# %%
example_data = example_data[training_features]
example_data
# Out:
#    Food Product  Main Ingredient  Sweetener    Fat/Oil  Seasoning  Allergens  \
# 0     12.397588        12.397588  12.397588  12.397588  12.397588  12.165608
# 1     12.397588        16.355000  12.319891  12.444471  12.397588  12.397588
#
#    Price  Customer rating
# 0   7.50              4.5
# 1   7.55              4.6

# %%
training_features
# Out:
# array(['Food Product', 'Main Ingredient', 'Sweetener', 'Fat/Oil',
#        'Seasoning', 'Allergens', 'Price', 'Customer rating'], dtype=object)

# %%
predictions = model.predict(example_data)

print("Predictions on example data:", predictions)
# Out:
# Predictions on example data: [1 0]
